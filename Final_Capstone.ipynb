# %% [markdown]
# # Import Necessary Libraries

# %% [markdown]
# # download installs needed for folium/geopy

# %%
# !conda install -c conda-forge geopy --yes 
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  22.67 MB/s
# geopy-1.17.0-p 100% |################################| Time: 0:00:00  35.60 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  30.95 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  35.67 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  39.23 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  49.83 MB/s

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# # Define Foursquare credentials and version

# %%
CLIENT_ID = 'DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO' # your Foursquare ID
CLIENT_SECRET = 'TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO
# CLIENT_SECRET:TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT

# %% [markdown]
# # Washington DC Geo Coordinates

# %% [markdown]
# # Latitude: 38.8951100° Longitude: -77.0363700°

# %% [markdown]
# # Lets search for chinese places around the area

# %%
latitude = 38.8951100
longitude = -77.0363700

search_query = 'Chinese'
# CategoryID is for food
categoryID = '4d4b7105d754a06374d81259'
radius = 3200
print(search_query + ' .... OK!')
# Out:
# Chinese .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query,categoryID, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO&client_secret=TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT&ll=38.89511,-77.03637&v=20180604&query=Chinese&categoryId=4d4b7105d754a06374d81259&radius=3200&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c0cae8bf594df190159d93d'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4f3210c319833175d60d1361',
#     'location': {'address': '510 I St NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 1566,
#      'formattedAddress': ['510 I St NW', 'Washington, D.C.', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900792,
#        'lng': -77.019831}],
#      'lat': 38.900792,
#      'lng': -77.019831,
#      'state': 'D.C.'},
#     'name': 'Chinese Consolidated Bnvlnt',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4be38508d27a20a1d492925b',
#     'location': {'address': '103 Rhode Island Ave NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': 'Rhode Island Ave and 1st St NW',
#      'distance': 3062,
#      'formattedAddress': ['103 Rhode Island Ave NW (Rhode Island Ave and 1st St NW)',
#       'Washington, D.C. 20001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.915657679860814,
#        'lng': -77.01285860877674}],
#      'lat': 38.915657679860814,
#      'lng': -77.01285860877674,
#      'postalCode': '20001',
#      'state': 'D.C.'},
#     'name': 'Chinese Dragon Carry-Out',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f32aebf19836c91c7ef7c95',
#     'location': {'address': '103 Rhode Island Ave NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 3110,
#      'formattedAddress': ['103 Rhode Island Ave NW',
#       'Washington, D.C.',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.915699,
#        'lng': -77.0121}],
#      'lat': 38.915699,
#      'lng': -77.0121,
#      'state': 'D.C.'},
#     'name': 'Chinese Dragon',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '5987e7d6b9a5a866d5b6c0d4',
#     'location': {'cc': 'US',
#      'city': 'Milford',
#      'country': 'United States',
#      'distance': 2207,
#      'formattedAddress': ['Milford, CT', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.911498,
#        'lng': -77.022013}],
#      'lat': 38.911498,
#      'lng': -77.022013,
#      'state': 'CT'},
#     'name': 'Chinese Zodiac',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'delivery': {'id': '69386',
#      'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'grubhub'},
#      'url': 'https://www.grubhub.com/restaurant/wok--roll-chinatown-604-h-st-nw-washington/69386?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=69386'},
#     'hasPerk': False,
#     'id': '4b3d40f5f964a520039125e3',
#     'location': {'address': '604 H St. NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': 'at Gallery Pl.',
#      'distance': 1470,
#      'formattedAddress': ['604 H St. NW (at Gallery Pl.)',
#       'Washington, D.C. 20001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.899568,
#        'lng': -77.020388}],
#      'lat': 38.899568,
#      'lng': -77.020388,
#      'postalCode': '20001',
#      'state': 'D.C.'},
#     'name': 'Wok and Roll',
#     'referralId': 'v-1544334987',
#     'venuePage': {'id': '85996128'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ac7d33df964a520f6b920e3',
#     'location': {'address': '610 H St NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 1452,
#      'formattedAddress': ['610 H St NW',
#       'Washington, D.C. 20001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.899552,
#        'lng': -77.02061}],
#      'lat': 38.899552,
#      'lng': -77.02061,
#      'postalCode': '20001',
#      'state': 'D.C.'},
#     'name': 'New Big Wong',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4dd86316d4c05d5097026eb4',
#     'location': {'address': '170 R Street, NE',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': 'North Capitol',
#      'distance': 3071,
#      'formattedAddress': ['170 R Street, NE (North Capitol)',
#       'Washington, D.C.',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.912686941921606,
#        'lng': -77.00903241981698}],
#      'lat': 38.912686941921606,
#      'lng': -77.00903241981698,
#      'state': 'D.C.'},
#     'name': 'Yeung Fong Chinese',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4a50febff964a52062b01fe3',
#     'location': {'address': '509 H St NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': 'btwn N 5th St. And N 6th St.',
#      'distance': 1570,
#      'formattedAddress': ['509 H St NW (btwn N 5th St. And N 6th St.)',
#       'Washington, D.C. 20001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.899982,
#        'lng': -77.019352}],
#      'lat': 38.899982,
#      'lng': -77.019352,
#      'postalCode': '20001',
#      'state': 'D.C.'},
#     'name': 'Full Kee Restaurant',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'delivery': {'id': '69759',
#      'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'grubhub'},
#      'url': 'https://www.grubhub.com/restaurant/eastern-carry-out-1784-florida-ave-nw-washington/69759?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=69759'},
#     'hasPerk': False,
#     'id': '4e4e6dbfbd4101d0d7a9f314',
#     'location': {'address': '1784 Florida Ave NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': '18th Street NW',
#      'distance': 2487,
#      'formattedAddress': ['1784 Florida Ave NW (18th Street NW)',
#       'Washington, D.C. 20009',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91708190312442,
#        'lng': -77.04161645296502}],
#      'lat': 38.91708190312442,
#      'lng': -77.04161645296502,
#      'postalCode': '20009',
#      'state': 'D.C.'},
#     'name': 'Eastern Carryout',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '52378c2511d2d607f3a40dd2',
#     'location': {'address': '2600 Connecticut Ave. NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 3457,
#      'formattedAddress': ['2600 Connecticut Ave. NW',
#       'Washington, D.C. 20008',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.92363091989049,
#        'lng': -77.05218788304806}],
#      'lat': 38.92363091989049,
#      'lng': -77.05218788304806,
#      'postalCode': '20008',
#      'state': 'D.C.'},
#     'name': "Eddie's Cafe Chinese Cuisine",
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4f4378f719834bc91f571254',
#     'location': {'address': '1734 Wisconsin Ave NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 3386,
#      'formattedAddress': ['1734 Wisconsin Ave NW',
#       'Washington, D.C.',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9142,
#        'lng': -77.066803}],
#      'lat': 38.9142,
#      'lng': -77.066803,
#      'state': 'D.C.'},
#     'name': 'Pagoda Chinese Restaurant',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4dcef002d164679b8d0d169e',
#     'location': {'address': '1501 N Capitol St NE',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 2871,
#      'formattedAddress': ['1501 N Capitol St NE',
#       'Washington, D.C. 20002',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90963843611398,
#        'lng': -77.00897978077974}],
#      'lat': 38.90963843611398,
#      'lng': -77.00897978077974,
#      'postalCode': '20002',
#      'state': 'D.C.'},
#     'name': 'Full Yum Carryout',
#     'referralId': 'v-1544334987'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'delivery': {'id': '76446',
#      'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'grubhub'},
#      'url': 'https://www.grubhub.com/restaurant/new-dynasty-2020-p-st-nw-washington/76446?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=76446'},
#     'hasPerk': False,
#     'id': '49e6603af964a52040641fe3',
#     'location': {'address': '2020 P St NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'crossStreet': '21st',
#      'distance': 1806,
#      'formattedAddress': ['2020 P St NW (21st)',
#       'Washington, D.C. 20036',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90957833159901,
#        'lng': -77.04581458390555}],
#      'lat': 38.90957833159901,
#      'lng': -77.04581458390555,
#      'postalCode': '20036',
#      'state': 'D.C.'},
#     'name': 'New Dynasty',
#     'referralId': 'v-1544334987',
#     'venuePage': {'id': '42332828'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4e4e5f74bd4101d0d7a8b69f',
#     'location': {'address': '2479 18th St NW',
#      'cc': 'US',
#      'city': 'Washington',
#      'country': 'United States',
#      'distance': 3502,
#      'formattedAddress': ['2479 18th St NW',
#       'Washington, D.C. 20009',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.924255,
#        'lng': -77.051608}],
#      'lat': 38.924255,
#      'lng': -77.051608,
#      'postalCode': '20009',
#      'state': 'D.C.'},
#     'name': 'Violet Garden',
#     'referralId': 'v-1544334987'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 1  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 2  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 3  [{'icon': {'suffix': '.png', 'prefix': 'https:...         NaN
# 4  [{'icon': {'suffix': '.png', 'prefix': 'https:...       69386
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/wok--roll-c...
#
#    hasPerk                        id         location.address     ...       \
# 0    False  4f3210c319833175d60d1361              510 I St NW     ...
# 1    False  4be38508d27a20a1d492925b  103 Rhode Island Ave NW     ...
# 2    False  4f32aebf19836c91c7ef7c95  103 Rhode Island Ave NW     ...
# 3    False  5987e7d6b9a5a866d5b6c0d4                      NaN     ...
# 4    False  4b3d40f5f964a520039125e3             604 H St. NW     ...
#
#   location.distance                          location.formattedAddress  \
# 0              1566     [510 I St NW, Washington, D.C., United States]
# 1              3062  [103 Rhode Island Ave NW (Rhode Island Ave and...
# 2              3110  [103 Rhode Island Ave NW, Washington, D.C., Un...
# 3              2207                       [Milford, CT, United States]
# 4              1470  [604 H St. NW (at Gallery Pl.), Washington, D....
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'lat': 38.900792, 'lng': -77.019831, 'label'...    38.900792
# 1  [{'lat': 38.915657679860814, 'lng': -77.012858...    38.915658
# 2  [{'lat': 38.915699, 'lng': -77.0121, 'label': ...    38.915699
# 3  [{'lat': 38.911498, 'lng': -77.022013, 'label'...    38.911498
# 4  [{'lat': 38.899568, 'lng': -77.020388, 'label'...    38.899568
#
#    location.lng location.postalCode location.state  \
# 0    -77.019831                 NaN           D.C.
# 1    -77.012859               20001           D.C.
# 2    -77.012100                 NaN           D.C.
# 3    -77.022013                 NaN             CT
# 4    -77.020388               20001           D.C.
#
#                           name    referralId venuePage.id
# 0  Chinese Consolidated Bnvlnt  v-1544334987          NaN
# 1     Chinese Dragon Carry-Out  v-1544334987          NaN
# 2               Chinese Dragon  v-1544334987          NaN
# 3               Chinese Zodiac  v-1544334987          NaN
# 4                 Wok and Roll  v-1544334987     85996128
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                             name          categories  \
# 0    Chinese Consolidated Bnvlnt  Chinese Restaurant
# 1       Chinese Dragon Carry-Out  Chinese Restaurant
# 2                 Chinese Dragon                Food
# 3                 Chinese Zodiac  Chinese Restaurant
# 4                   Wok and Roll    Sushi Restaurant
# 5                   New Big Wong  Chinese Restaurant
# 6             Yeung Fong Chinese  Chinese Restaurant
# 7            Full Kee Restaurant  Chinese Restaurant
# 8               Eastern Carryout  Chinese Restaurant
# 9   Eddie's Cafe Chinese Cuisine  Chinese Restaurant
# 10     Pagoda Chinese Restaurant  Chinese Restaurant
# 11             Full Yum Carryout  Chinese Restaurant
# 12                   New Dynasty  Chinese Restaurant
# 13                 Violet Garden    Sushi Restaurant
#
#                      address  cc        city        country  \
# 0                510 I St NW  US  Washington  United States
# 1    103 Rhode Island Ave NW  US  Washington  United States
# 2    103 Rhode Island Ave NW  US  Washington  United States
# 3                        NaN  US     Milford  United States
# 4               604 H St. NW  US  Washington  United States
# 5                610 H St NW  US  Washington  United States
# 6           170 R Street, NE  US  Washington  United States
# 7                509 H St NW  US  Washington  United States
# 8        1784 Florida Ave NW  US  Washington  United States
# 9   2600 Connecticut Ave. NW  US  Washington  United States
# 10     1734 Wisconsin Ave NW  US  Washington  United States
# 11      1501 N Capitol St NE  US  Washington  United States
# 12              2020 P St NW  US  Washington  United States
# 13           2479 18th St NW  US  Washington  United States
#
#                        crossStreet  distance  \
# 0                              NaN      1566
# 1   Rhode Island Ave and 1st St NW      3062
# 2                              NaN      3110
# 3                              NaN      2207
# 4                   at Gallery Pl.      1470
# 5                              NaN      1452
# 6                    North Capitol      3071
# 7     btwn N 5th St. And N 6th St.      1570
# 8                   18th Street NW      2487
# 9                              NaN      3457
# 10                             NaN      3386
# 11                             NaN      2871
# 12                            21st      1806
# 13                             NaN      3502
#
#                                      formattedAddress  \
# 0      [510 I St NW, Washington, D.C., United States]
# 1   [103 Rhode Island Ave NW (Rhode Island Ave and...
# 2   [103 Rhode Island Ave NW, Washington, D.C., Un...
# 3                        [Milford, CT, United States]
# 4   [604 H St. NW (at Gallery Pl.), Washington, D....
# 5   [610 H St NW, Washington, D.C. 20001, United S...
# 6   [170 R Street, NE (North Capitol), Washington,...
# 7   [509 H St NW (btwn N 5th St. And N 6th St.), W...
# 8   [1784 Florida Ave NW (18th Street NW), Washing...
# 9   [2600 Connecticut Ave. NW, Washington, D.C. 20...
# 10  [1734 Wisconsin Ave NW, Washington, D.C., Unit...
# 11  [1501 N Capitol St NE, Washington, D.C. 20002,...
# 12  [2020 P St NW (21st), Washington, D.C. 20036, ...
# 13  [2479 18th St NW, Washington, D.C. 20009, Unit...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 38.900792, 'lng': -77.019831, 'label'...  38.900792 -77.019831
# 1   [{'lat': 38.915657679860814, 'lng': -77.012858...  38.915658 -77.012859
# 2   [{'lat': 38.915699, 'lng': -77.0121, 'label': ...  38.915699 -77.012100
# 3   [{'lat': 38.911498, 'lng': -77.022013, 'label'...  38.911498 -77.022013
# 4   [{'lat': 38.899568, 'lng': -77.020388, 'label'...  38.899568 -77.020388
# 5   [{'lat': 38.899552, 'lng': -77.02061, 'label':...  38.899552 -77.020610
# 6   [{'lat': 38.912686941921606, 'lng': -77.009032...  38.912687 -77.009032
# 7   [{'lat': 38.899982, 'lng': -77.019352, 'label'...  38.899982 -77.019352
# 8   [{'lat': 38.91708190312442, 'lng': -77.0416164...  38.917082 -77.041616
# 9   [{'lat': 38.92363091989049, 'lng': -77.0521878...  38.923631 -77.052188
# 10  [{'lat': 38.9142, 'lng': -77.066803, 'label': ...  38.914200 -77.066803
# 11  [{'lat': 38.90963843611398, 'lng': -77.0089797...  38.909638 -77.008980
# 12  [{'lat': 38.90957833159901, 'lng': -77.0458145...  38.909578 -77.045815
# 13  [{'lat': 38.924255, 'lng': -77.051608, 'label'...  38.924255 -77.051608
#
#    postalCode state                        id
# 0         NaN  D.C.  4f3210c319833175d60d1361
# 1       20001  D.C.  4be38508d27a20a1d492925b
# 2         NaN  D.C.  4f32aebf19836c91c7ef7c95
# 3         NaN    CT  5987e7d6b9a5a866d5b6c0d4
# 4       20001  D.C.  4b3d40f5f964a520039125e3
# 5       20001  D.C.  4ac7d33df964a520f6b920e3
# 6         NaN  D.C.  4dd86316d4c05d5097026eb4
# 7       20001  D.C.  4a50febff964a52062b01fe3
# 8       20009  D.C.  4e4e6dbfbd4101d0d7a9f314
# 9       20008  D.C.  52378c2511d2d607f3a40dd2
# 10        NaN  D.C.  4f4378f719834bc91f571254
# 11      20002  D.C.  4dcef002d164679b8d0d169e
# 12      20036  D.C.  49e6603af964a52040641fe3
# 13      20009  D.C.  4e4e5f74bd4101d0d7a8b69f

# %%
dataframe_filtered.name
# Out:
# 0      Chinese Consolidated Bnvlnt
# 1         Chinese Dragon Carry-Out
# 2                   Chinese Dragon
# 3                   Chinese Zodiac
# 4                     Wok and Roll
# 5                     New Big Wong
# 6               Yeung Fong Chinese
# 7              Full Kee Restaurant
# 8                 Eastern Carryout
# 9     Eddie's Cafe Chinese Cuisine
# 10       Pagoda Chinese Restaurant
# 11               Full Yum Carryout
# 12                     New Dynasty
# 13                   Violet Garden
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Capital

# add a red circle marker to represent the Capital
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Capital',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Chinese restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map of where all the chinese food buisnesses are that are around the capital building. 
# based on that info can narrow down a more specific area
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# based on the map we see that there are no chinese resturants to the west of the capital near foggy bottom. Knowing that tourists visit the capital and national mall every day that would be a good place to look at further.

# %% [markdown]
# Also we can explore what are the trending points nearby Foggy Bottom

# %%
t_latitude = 38.885011 
t_longitude = -76.999224

# define URL
t_url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, t_latitude, t_longitude, VERSION)

# send GET request and get trending venues
t_results = requests.get(t_url).json()
t_results
# Out:
# {'meta': {'code': 200, 'requestId': '5c0cb2624434b9040d825ec0'},
#  'response': {'venues': []}}

# %%
if len(t_results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = t_results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Based on the trending details, nothing was trending in and around foggy bottom at the moment. Maybe there were no chinese restaurants around Foggy Bottom.

# %% [markdown]
# Try the explore end point

# %%
e_latitude = 38.900840 
e_longitude = -77.050093 
e_radius = 500
e_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, e_latitude, e_longitude, VERSION, e_radius, LIMIT)
e_url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO&client_secret=TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT&ll=38.90084,-77.050093&v=20180604&radius=500&limit=30'

# %%
import requests
e_results = requests.get(e_url).json()
'There are {} around Foggy Bottom restaurant.'.format(len(e_results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Foggy Bottom restaurant.'

# %%
items = e_results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4e26e4bcb0fb1fae1dd7ea15-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d118951735',
#     'name': 'Grocery Store',
#     'pluralName': 'Grocery Stores',
#     'primary': True,
#     'shortName': 'Grocery Store'}],
#   'id': '4e26e4bcb0fb1fae1dd7ea15',
#   'location': {'address': '2201 I St NW',
#    'cc': 'US',
#    'city': 'Washington',
#    'country': 'United States',
#    'crossStreet': 'at 22nd St NW',
#    'distance': 88,
#    'formattedAddress': ['2201 I St NW (at 22nd St NW)',
#     'Washington, D.C. 20037',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 38.90084526199545,
#      'lng': -77.04907715320587}],
#    'lat': 38.90084526199545,
#    'lng': -77.04907715320587,
#    'postalCode': '20037',
#    'state': 'D.C.'},
#   'name': 'Whole Foods Market',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '74910107'}}}

# %%
e_dataframe = json_normalize(items) # flatten JSON
# filter columns
e_dataframe.head(5)
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'reasonName': 'globalInteractionReason', 'ty...
# 1              0  [{'reasonName': 'globalInteractionReason', 'ty...
# 2              0  [{'reasonName': 'globalInteractionReason', 'ty...
# 3              0  [{'reasonName': 'globalInteractionReason', 'ty...
# 4              0  [{'reasonName': 'globalInteractionReason', 'ty...
#
#                        referralId  \
# 0  e-0-4e26e4bcb0fb1fae1dd7ea15-0
# 1  e-0-4e17196a1495f6691bf85931-1
# 2  e-0-4e7fabb24690db1d41b6c283-2
# 3  e-0-4e83a5009adf2d8426cd2501-3
# 4  e-0-550a08a9498edc2769715a98-4
#
#                                     venue.categories venue.delivery.id  \
# 0  [{'icon': {'suffix': '.png', 'prefix': 'https:...               NaN
# 1  [{'icon': {'suffix': '.png', 'prefix': 'https:...               NaN
# 2  [{'icon': {'suffix': '.png', 'prefix': 'https:...               NaN
# 3  [{'icon': {'suffix': '.png', 'prefix': 'https:...               NaN
# 4  [{'icon': {'suffix': '.png', 'prefix': 'https:...            335379
#
#          venue.delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#         venue.delivery.provider.icon.prefix  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  https://fastly.4sqi.net/img/general/cap/
#
#   venue.delivery.provider.icon.sizes venue.delivery.provider.name  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                           [40, 50]                      grubhub
#
#                                   venue.delivery.url         ...          \
# 0                                                NaN         ...
# 1                                                NaN         ...
# 2                                                NaN         ...
# 3                                                NaN         ...
# 4  https://www.grubhub.com/restaurant/beefsteak-8...         ...
#
#                        venue.location.labeledLatLngs venue.location.lat  \
# 0  [{'lng': -77.04907715320587, 'label': 'display...          38.900845
# 1  [{'lng': -77.04957856798501, 'label': 'display...          38.900994
# 2  [{'lng': -77.04961414256549, 'label': 'display...          38.902289
# 3  [{'lng': -77.04985499382019, 'label': 'display...          38.901771
# 4  [{'lng': -77.04905546999852, 'label': 'display...          38.900550
#
#   venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0         -77.049077                         NaN                     20037
# 1         -77.049579                         NaN                     20052
# 2         -77.049614                         NaN                     20001
# 3         -77.049855                         NaN                     20052
# 4         -77.049055                         NaN                     20052
#
#   venue.location.state           venue.name venue.photos.count  \
# 0                 D.C.   Whole Foods Market                  0
# 1                 D.C.           sweetgreen                  0
# 2                 D.C.     District Commons                  0
# 3                 D.C.  Burger, Tap & Shake                  0
# 4                 D.C.            Beefsteak                  0
#
#   venue.photos.groups  venue.venuePage.id
# 0                  []            74910107
# 1                  []                 NaN
# 2                  []            83819103
# 3                  []                 NaN
# 4                  []           123629837
#
# [5 rows x 28 columns]

# %%
e_filtered_columns = ['venue.name', 'venue.categories'] + [col for col in e_dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
e_dataframe_filtered = e_dataframe.loc[:, e_filtered_columns]

# filter the category for each row
e_dataframe_filtered['venue.categories'] = e_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
e_dataframe_filtered.columns = [col.split('.')[-1] for col in e_dataframe_filtered.columns]

e_dataframe_filtered
# Out:
#                                     name                     categories  \
# 0                     Whole Foods Market                  Grocery Store
# 1                             sweetgreen                    Salad Place
# 2                       District Commons            American Restaurant
# 3                    Burger, Tap & Shake                   Burger Joint
# 4                              Beefsteak  Vegetarian / Vegan Restaurant
# 5                          Wiseguy Pizza                    Pizza Place
# 6                 Washington Circle Park                           Park
# 7                            Chick-fil-A           Fast Food Restaurant
# 8              Roti Modern Mediterranean       Mediterranean Restaurant
# 9           Marcel's by Robert Wiedmaier              French Restaurant
# 10        Captain Cookie and the Milkman                         Bakery
# 11                        Bluestone Lane                           Café
# 12              Melrose Georgetown Hotel                          Hotel
# 13                       GRK Fresh Greek               Greek Restaurant
# 14                     Lisner Auditorium          Performing Arts Venue
# 15                            Aroma Cafe                    Coffee Shop
# 16                   GWU University Yard                   College Quad
# 17                         The River Inn                          Hotel
# 18                 CIRCA at Foggy Bottom            American Restaurant
# 19                             Starbucks                    Coffee Shop
# 20         Foggy Bottom FRESHFARM Market                 Farmers Market
# 21                            Hotel Hive                          Hotel
# 22                        Hotel Lombardy                          Hotel
# 23                          Panera Bread                         Bakery
# 24                         Peet's Coffee                    Coffee Shop
# 25                       GW Delicatessen                  Deli / Bodega
# 26                          Urban Boxing           Gym / Fitness Center
# 27                                   Ris            American Restaurant
# 28  Equinox Sports Club Washington, D.C.                            Gym
# 29                      Founding Farmers            American Restaurant
#
#                          address  cc        city        country  \
# 0                   2201 I St NW  US  Washington  United States
# 1                   2221 I St NW  US  Washington  United States
# 2       2200 Pennsylvania Ave NW  US  Washington  United States
# 3       2200 Pennsylvania Ave NW  US  Washington  United States
# 4                 800 22nd St NW  US  Washington  United States
# 5                   2121 H St NW  US  Washington  United States
# 6           Washington Circle NW  US  Washington  United States
# 7   2121 H St Nw, District House  US  Washington  United States
# 8                   2221 I St NW  US  Washington  United States
# 9       2401 Pennsylvania Ave NW  US  Washington  United States
# 10      2000 Pennsylvania Ave NW  US  Washington  United States
# 11               1100 23rd St NW  US  Washington  United States
# 12      2430 Pennsylvania Ave NW  US  Washington  United States
# 13                  2121 H St NW  US  Washington  United States
# 14                730 21st St NW  US  Washington  United States
# 15      2401 Pennsylvania Ave NW  US  Washington  United States
# 16                  2000 H St NW  US  Washington  United States
# 17                924 25th St NW  US  Washington  United States
# 18                  2023 I St NW  US  Washington  United States
# 19                  2130 H St NW  US  Washington  United States
# 20                          I St  US  Washington  United States
# 21                  2224 F St NW  US  Washington  United States
# 22      2019 Pennsylvania Ave NW  US  Washington  United States
# 23            800 21st Street NW  US  Washington  United States
# 24             2121 H St NW #131  US  Washington  United States
# 25                  2133 G St NW  US  Washington  United States
# 26               1116 24th St NW  US  Washington  United States
# 27                  2275 L St NW  US  Washington  United States
# 28              1170 22nd St NW.  US  Washington  United States
# 29      1924 Pennsylvania Ave NW  US  Washington  United States
#
#                             crossStreet  distance  \
# 0                         at 22nd St NW        88
# 1                btwn 22nd & 23rd St NW        47
# 2                         at 22nd St NW       166
# 3                  at Washington Cir NW       105
# 4                            at I St NW        95
# 5                                   NaN       221
# 6                K St NW and 23rd St NW       187
# 7                   btwn 21st & 22nd St       222
# 8                         at 23rd St NW        45
# 9                         at 24th St NW       342
# 10                        at 21st St NW       328
# 11                           at L St NW       340
# 12                                  NaN       343
# 13                           at M St NW       218
# 14                           at H St NW       309
# 15                        at 24th St NW       295
# 16         btwn 20th St NW & 21st St NW       408
# 17                                  NaN       302
# 18                        at 23rd St NW        11
# 19                        at 22nd St NW       203
# 20  btwn New Hampshire and 24th St., NW        21
# 21                   at Virginia Ave NW       411
# 22                                  NaN       369
# 23                                  NaN       271
# 24               btwn 21st & 22nd St NW       198
# 25                      btw 21st & 22nd       306
# 26                     btwn L & M St NW       400
# 27                                  NaN       355
# 28                              at M St       451
# 29                           20th St NW       481
#
#                                      formattedAddress  \
# 0   [2201 I St NW (at 22nd St NW), Washington, D.C...
# 1   [2221 I St NW (btwn 22nd & 23rd St NW), Washin...
# 2   [2200 Pennsylvania Ave NW (at 22nd St NW), Was...
# 3   [2200 Pennsylvania Ave NW (at Washington Cir N...
# 4   [800 22nd St NW (at I St NW), Washington, D.C....
# 5   [2121 H St NW, Washington, D.C. 20052, United ...
# 6   [Washington Circle NW (K St NW and 23rd St NW)...
# 7   [2121 H St Nw, District House (btwn 21st & 22n...
# 8   [2221 I St NW (at 23rd St NW), Washington, D.C...
# 9   [2401 Pennsylvania Ave NW (at 24th St NW), Was...
# 10  [2000 Pennsylvania Ave NW (at 21st St NW), Was...
# 11  [1100 23rd St NW (at L St NW), Washington, D.C...
# 12  [2430 Pennsylvania Ave NW, Washington, D.C. 20...
# 13  [2121 H St NW (at M St NW), Washington, D.C. 2...
# 14  [730 21st St NW (at H St NW), Washington, D.C....
# 15  [2401 Pennsylvania Ave NW (at 24th St NW), Was...
# 16  [2000 H St NW (btwn 20th St NW & 21st St NW), ...
# 17  [924 25th St NW, Washington, D.C. 20037, Unite...
# 18  [2023 I St NW (at 23rd St NW), Washington, D.C...
# 19  [2130 H St NW (at 22nd St NW), Washington, D.C...
# 20  [I St (btwn New Hampshire and 24th St., NW), W...
# 21  [2224 F St NW (at Virginia Ave NW), Washington...
# 22  [2019 Pennsylvania Ave NW, Washington, D.C. 20...
# 23  [800 21st Street NW, Washington, D.C. 20052, U...
# 24  [2121 H St NW #131 (btwn 21st & 22nd St NW), W...
# 25  [2133 G St NW (btw 21st & 22nd), Washington, D...
# 26  [1116 24th St NW (btwn L & M St NW), Washingto...
# 27  [2275 L St NW, Washington, D.C. 20037, United ...
# 28  [1170 22nd St NW. (at M St), Washington, D.C. ...
# 29  [1924 Pennsylvania Ave NW (20th St NW), Washin...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': -77.04907715320587, 'label': 'display...  38.900845 -77.049077
# 1   [{'lng': -77.04957856798501, 'label': 'display...  38.900994 -77.049579
# 2   [{'lng': -77.04961414256549, 'label': 'display...  38.902289 -77.049614
# 3   [{'lng': -77.04985499382019, 'label': 'display...  38.901771 -77.049855
# 4   [{'lng': -77.04905546999852, 'label': 'display...  38.900550 -77.049055
# 5   [{'lng': -77.04783091555205, 'label': 'display...  38.899915 -77.047831
# 6   [{'lng': -77.05012321472168, 'label': 'display...  38.902522 -77.050123
# 7   [{'lng': -77.047711, 'label': 'display', 'lat'...  38.900081 -77.047711
# 8   [{'lng': -77.04958140850067, 'label': 'display...  38.900921 -77.049581
# 9   [{'lng': -77.05222560926947, 'label': 'display...  38.903433 -77.052226
# 10  [{'lng': -77.0463150367463, 'label': 'display'...  38.900599 -77.046315
# 11  [{'lng': -77.050422, 'label': 'display', 'lat'...  38.903889 -77.050422
# 12  [{'lng': -77.05249497663534, 'label': 'display...  38.903295 -77.052495
# 13  [{'lng': -77.047809, 'label': 'display', 'lat'...  38.900004 -77.047809
# 14  [{'lng': -77.04707808541326, 'label': 'display...  38.899356 -77.047078
# 15  [{'lng': -77.05154787442379, 'label': 'display...  38.903241 -77.051548
# 16  [{'lng': -77.04584626049449, 'label': 'display...  38.899240 -77.045846
# 17  [{'lng': -77.05349826487138, 'label': 'display...  38.901439 -77.053498
# 18  [{'lng': -77.04996246903572, 'label': 'display...  38.900848 -77.049962
# 19  [{'lng': -77.0486, 'label': 'display', 'lat': ...  38.899430 -77.048600
# 20  [{'lng': -77.0503270336628, 'label': 'display'...  38.900775 -77.050327
# 21  [{'lng': -77.04983007143048, 'label': 'display...  38.897152 -77.049830
# 22  [{'lng': -77.04588989102214, 'label': 'display...  38.901409 -77.045890
# 23  [{'lng': -77.04715669155121, 'label': 'display...  38.899984 -77.047157
# 24  [{'lng': -77.04780663525243, 'label': 'display...  38.900716 -77.047807
# 25  [{'lng': -77.04828670490485, 'label': 'display...  38.898477 -77.048287
# 26  [{'lng': -77.0516236692373, 'label': 'display'...  38.904233 -77.051624
# 27  [{'lng': -77.0500441019574, 'label': 'display'...  38.904032 -77.050044
# 28  [{'lng': -77.048999, 'label': 'display', 'lat'...  38.904808 -77.048999
# 29  [{'lng': -77.04459249973297, 'label': 'display...  38.900239 -77.044592
#
#                      neighborhood postalCode state                        id
# 0                             NaN      20037  D.C.  4e26e4bcb0fb1fae1dd7ea15
# 1                             NaN      20052  D.C.  4e17196a1495f6691bf85931
# 2                             NaN      20001  D.C.  4e7fabb24690db1d41b6c283
# 3                             NaN      20052  D.C.  4e83a5009adf2d8426cd2501
# 4                             NaN      20052  D.C.  550a08a9498edc2769715a98
# 5                             NaN      20052  D.C.  5852f75e30ecc632ca9b702a
# 6                             NaN      20037  D.C.  4b9978aef964a520c47c35e3
# 7                             NaN      20052  D.C.  58b0b2e62cba2240731ccfea
# 8                             NaN      20037  D.C.  4e239cb8628469a5742c71c6
# 9                             NaN      20037  D.C.  4aad4d9ff964a520935f20e3
# 10                            NaN      20037  D.C.  5092acf5e4b0d9b14fd4f7c0
# 11                            NaN      20037  D.C.  5a5f795fbb8d3614bbf31928
# 12                            NaN      20037  D.C.  4da70ab1fa8ca99428544132
# 13  Connecticut Avenue - K Street      20036  D.C.  53c14089498ea554b4ae5b8b
# 14                            NaN      20006  D.C.  45cd64bdf964a5208c421fe3
# 15                            NaN        NaN  D.C.  4bae0ac5f964a520db7d3be3
# 16                            NaN      20052  D.C.  4b93f7cff964a520bb5d34e3
# 17                            NaN      20037  D.C.  4b4ea3a0f964a52027f326e3
# 18                            NaN      20037  D.C.  4e0cd9921f6e9300e4ea777c
# 19                            NaN      20052  D.C.  4a54d2f3f964a52053b31fe3
# 20                            NaN      20037  D.C.  4a1474d5f964a52041781fe3
# 21                            NaN      20037  D.C.  588a4342debdf635773ca0ef
# 22                            NaN      20006  D.C.  4cfe8ff466ee9eb0bed6a64e
# 23                            NaN      20052  D.C.  5a562c1981635b54dd548726
# 24                            NaN      20052  D.C.  587486bef68d8d74ff2b493e
# 25                            NaN      20037  D.C.  4a521abaf964a52041b11fe3
# 26                            NaN      20037  D.C.  4a7767e9f964a52062e41fe3
# 27                            NaN      20037  D.C.  4b182400f964a520a2cd23e3
# 28                            NaN      20037  D.C.  4a77ac8df964a520fce41fe3
# 29                            NaN      20006  D.C.  4a469855f964a5202aa91fe3

# %%
venues_map = folium.Map(location=[e_latitude, e_longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [e_latitude, e_longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(e_dataframe_filtered.lat, e_dataframe_filtered.lng, e_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Based on the map, we could see there are american restaurants/hotels are there, but there is no sign of chinese restaurant. So this must be a place to invest one.

# %%
s_latitude = 38.900840
s_longitude = -77.050093 
s_query = 'chinese'
s_radius = 500
s_url = 'https://api.foursquare.com/v2/venues/suggestcompletion?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, s_latitude, s_longitude, VERSION, s_query, s_radius)
s_url
# Out:
# 'https://api.foursquare.com/v2/venues/suggestcompletion?client_id=DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO&client_secret=TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT&ll=38.90084,-77.050093&v=20180604&query=chinese&radius=500'

# %%
import requests
s_results = requests.get(s_url).json()

# %%
cats = s_results['response']['minivenues']
cats[0]
# Out:
# {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d124941735',
#    'name': 'Office',
#    'pluralName': 'Offices',
#    'shortName': 'Office'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#     'suffix': '.png'},
#    'id': '4d4b7105d754a06375d81259',
#    'name': 'Professional & Other Places',
#    'pluralName': 'Professional & Other Places',
#    'shortName': 'Professional'}],
#  'hasPerk': False,
#  'id': '4e456a7d315143b381d318f6',
#  'location': {'address': '618-20 H Street NW',
#   'city': 'Washington',
#   'country': 'US',
#   'distance': 569,
#   'lat': 38.89771308995573,
#   'lng': -77.04488754775426,
#   'postalCode': '20006',
#   'state': 'DC'},
#  'name': 'On Leong Chinese Merchant Association'}

# %%
s_dataframe = json_normalize(cats) # flatten JSON
s_dataframe.head(5)
# Out:
#                                           categories  hasPerk  \
# 0  [{'pluralName': 'Offices', 'icon': {'suffix': ...    False
# 1  [{'pluralName': 'Arts & Entertainment', 'icon'...    False
# 2  [{'pluralName': 'Acupuncturists', 'icon': {'su...    False
# 3  [{'pluralName': 'Acupuncturists', 'icon': {'su...    False
# 4  [{'pluralName': 'Acupuncturists', 'icon': {'su...    False
#
#                          id                 location.address    location.city  \
# 0  4e456a7d315143b381d318f6               618-20 H Street NW       Washington
# 1  4e134c9f1838f8ad816cd1b3                              NaN  Washington D.C.
# 2  53b2dc3d498e1978c892da4f  910 17th Street, NW, Suite 1020       Washington
# 3  56298b5e498e4901a42eb7a4          910 17th St NW Ste 1020       Washington
# 4  4eb17285e5e8c0f5bd37400b              1010 Vermont Ave NW       Washington
#
#   location.country location.crossStreet  location.distance  location.lat  \
# 0               US                  NaN                569     38.897713
# 1               US                  NaN                790     38.895137
# 2               US                  NaN                903     38.901997
# 3               US               KSt NW                912     38.901888
# 4               US                  NaN               1439     38.902973
#
#    location.lng location.postalCode location.state  \
# 0    -77.044888               20006             DC
# 1    -77.055537                 NaN             DC
# 2    -77.039767               20006             DC
# 3    -77.039652               20006             DC
# 4    -77.033708               20005             DC
#
#                                          name
# 0       On Leong Chinese Merchant Association
# 1               Kennedy Center Chinese Lounge
# 2        Yao Shan Center for Chinese Medicine
# 3  Leanne Ekstrom Acupuncture & Chinese Herbs
# 4         Chinese Acupuncture and Herb Center

# %%
s_filtered_columns = ['name', 'categories'] + [col for col in s_dataframe.columns if col.startswith('location.')] + ['id']
s_dataframe_filtered = s_dataframe.loc[:, s_filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
s_dataframe_filtered['categories'] = s_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
s_dataframe_filtered.columns = [col.split('.')[-1] for col in s_dataframe_filtered.columns]

s_dataframe_filtered.head(14)
# Out:
#                                           name            categories  \
# 0        On Leong Chinese Merchant Association                Office
# 1                Kennedy Center Chinese Lounge  Arts & Entertainment
# 2         Yao Shan Center for Chinese Medicine         Acupuncturist
# 3   Leanne Ekstrom Acupuncture & Chinese Herbs         Acupuncturist
# 4          Chinese Acupuncture and Herb Center         Acupuncturist
# 5                   Chinese Acupuncture Clinic         Acupuncturist
# 6                    Pagoda Chinese Restaurant    Chinese Restaurant
# 7                     Chinese Community Church                Church
# 8                 Eddie's Cafe Chinese Cuisine    Chinese Restaurant
# 9                      chinese cultural center    College Rec Center
# 10                         The Chinese Embassy   Embassy / Consulate
# 11                        Chinese Liquor Store              Pharmacy
# 12                 Chinese Consolidated Bnvlnt    Chinese Restaurant
# 13                              Chinese Zodiac    Chinese Restaurant
#
#                             address             city country crossStreet  \
# 0                618-20 H Street NW       Washington      US         NaN
# 1                               NaN  Washington D.C.      US         NaN
# 2   910 17th Street, NW, Suite 1020       Washington      US         NaN
# 3           910 17th St NW Ste 1020       Washington      US      KSt NW
# 4               1010 Vermont Ave NW       Washington      US         NaN
# 5       1010 Vermont Ave NW ste 712  Washington D.C.      US         NaN
# 6             1734 Wisconsin Ave NW       Washington      US         NaN
# 7                       500 I St NW       Washington      US         NaN
# 8          2600 Connecticut Ave. NW  Washington D.C.      US         NaN
# 9                               NaN       Washington      US         NaN
# 10    2201 Wisconsin Ave NW Ste 110       Washington      US     Florida
# 11                              NaN       Washington      US         NaN
# 12                      510 I St NW       Washington      US         NaN
# 13                              NaN          Milford      US         NaN
#
#     distance        lat        lng postalCode state                        id
# 0        569  38.897713 -77.044888      20006    DC  4e456a7d315143b381d318f6
# 1        790  38.895137 -77.055537        NaN    DC  4e134c9f1838f8ad816cd1b3
# 2        903  38.901997 -77.039767      20006    DC  53b2dc3d498e1978c892da4f
# 3        912  38.901888 -77.039652      20006    DC  56298b5e498e4901a42eb7a4
# 4       1439  38.902973 -77.033708      20005    DC  4eb17285e5e8c0f5bd37400b
# 5       1531  38.905469 -77.033443        NaN    DC  4e272fdab0fb1fae1ddb59a9
# 6       2075  38.914200 -77.066803        NaN    DC  4f4378f719834bc91f571254
# 7       2698  38.900802 -77.018947      20001    DC  4c8f7d3ad2aea093c0ccd669
# 8       2543  38.923631 -77.052188      20008  D.C.  52378c2511d2d607f3a40dd2
# 9       2546  38.899774 -77.020735      20001    DC  4b81a30cf964a52070b430e3
# 10      2699  38.919394 -77.070165      20007    DC  51003d11e4b0b671fb8b8c65
# 11      2593  38.899785 -77.020185      20001    DC  4c51e00c7f6e20a189dfd1ea
# 12      2621  38.900792 -77.019831        NaN    DC  4f3210c319833175d60d1361
# 13      2706  38.911498 -77.022013        NaN    CT  5987e7d6b9a5a866d5b6c0d4

# %%
s_venues_map = folium.Map(location=[s_latitude, s_longitude], zoom_start=12) # generate map centred around FB

# add FB as a red circle mark
folium.features.CircleMarker(
    [s_latitude, s_longitude],
    radius=10,
    popup='Foggy Bottom',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(s_venues_map)

# add popular spots to the map as blue circle markers
for lat, lng, cat in zip(s_dataframe_filtered.lat, s_dataframe_filtered.lng, s_dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=folium.Popup(cat ,parse_html=True),
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(s_venues_map)

s_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Chinese restaurant nearest to Foggy bottom is in China town

# %% [markdown]
# Checking the prices for the restaurant

# %%
#General price of Chiense in DC.
#plugging in different venue id's most depeict a cheaper price point
venue_id = '4dcef002d164679b8d0d169e'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4dcef002d164679b8d0d169e?client_id=DNOP1XHXDAI0DNBMPXQR3T44FUMSNPA420HE35EW3AYMXESO&client_secret=TQAL1UO0X4QEJKD44I2EHLWKAQNYWAZT1ANOVHE2ACDY2SVT&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['inbox', 'dislike', 'allowMenuUrlEdit', 'reasons', 'tips', 'location', 'contact', 'likes', 'createdAt', 'hereNow', 'ok', 'beenHere', 'specials', 'photos', 'bestPhoto', 'stats', 'timeZone', 'price', 'listed', 'categories', 'pageUpdates', 'shortUrl', 'name', 'verified', 'canonicalUrl', 'id', 'attributes'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}],
#     'name': 'Price',
#     'summary': '$',
#     'type': 'price'},
#    {'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'No'}],
#     'name': 'Reservations',
#     'type': 'reservations'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}],
#     'name': 'Outdoor Seating',
#     'type': 'outdoorSeating'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1526784440,
#   'height': 1900,
#   'id': '5b00e1b860255e002c1a1f6b',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'},
#   'suffix': '/10707_A_ZczM0ZXfOCOX9uZ9-T2rQMnH3DKaNKRf9u1Bna5eY.jpg',
#   'visibility': 'public',
#   'width': 1425},
#  'canonicalUrl': 'https://foursquare.com/v/full-yum-carryout/4dcef002d164679b8d0d169e',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d145941735',
#    'name': 'Chinese Restaurant',
#    'pluralName': 'Chinese Restaurants',
#    'primary': True,
#    'shortName': 'Chinese'}],
#  'contact': {},
#  'createdAt': 1305407490,
#  'dislike': False,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'id': '4dcef002d164679b8d0d169e',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 1,
#   'groups': [{'count': 1,
#     'items': [{'firstName': 'George',
#       'gender': 'male',
#       'id': '140705417',
#       'lastName': 'Hughes',
#       'photo': {'default': True,
#        'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png'}}],
#     'type': 'others'}],
#   'summary': '1 Like'},
#  'listed': {'count': 0,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '1501 N Capitol St NE',
#   'cc': 'US',
#   'city': 'Washington',
#   'country': 'United States',
#   'formattedAddress': ['1501 N Capitol St NE',
#    'Washington, D.C. 20002',
#    'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 38.90963843611398,
#     'lng': -77.00897978077974}],
#   'lat': 38.90963843611398,
#   'lng': -77.00897978077974,
#   'postalCode': '20002',
#   'state': 'D.C.'},
#  'name': 'Full Yum Carryout',
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 12,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 12,
#     'items': [{'createdAt': 1526784440,
#       'height': 1900,
#       'id': '5b00e1b860255e002c1a1f6b',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Swarm for Android',
#        'url': 'https://www.swarmapp.com'},
#       'suffix': '/10707_A_ZczM0ZXfOCOX9uZ9-T2rQMnH3DKaNKRf9u1Bna5eY.jpg',
#       'user': {'firstName': 'jbrotherlove',
#        'gender': 'male',
#        'id': '10707',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/TEO154RTNPM2SRIA.jpg'}},
#       'visibility': 'public',
#       'width': 1425}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'price': {'currency': '$', 'message': 'Cheap', 'tier': 1},
#  'reasons': {'count': 0, 'items': []},
#  'shortUrl': 'http://4sq.com/lCEWXK',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 2},
#  'timeZone': 'America/New_York',
#  'tips': {'count': 2,
#   'groups': [{'count': 2,
#     'items': [{'agreeCount': 0,
#       'canonicalUrl': 'https://foursquare.com/item/52e4a6fb498eda40bba31301',
#       'createdAt': 1390716667,
#       'disagreeCount': 0,
#       'id': '52e4a6fb498eda40bba31301',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'text': 'Not the greatest.',
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'Paris',
#        'gender': 'female',
#        'id': '21909126',
#        'lastName': 'Waterman',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/21909126-XTHTEPXSGC2IDZJJ.jpg'}}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'verified': False}

# %%
print(result['response']['venue']['price'])
# Out:
# {'message': 'Cheap', 'currency': '$', 'tier': 1}
